# %% [markdown]
# ### 실습 문제 2. NumPy만을 사용해서 mean filter를 제작하시오.
# NumPy 라이브러리와 파이썬 내장함수만을 사용해서 함수 'meanfilter'를 완성해 보세요.
# - 조건:
#     - 함수 입력값: image (type:ndarray)
#     - 함수 출력값(반환값): mean filter가 적용된 이미지의 ndarray

# %%
from PIL import Image
import numpy as np

# %%
image = Image.open("sample_image_meanfilter.jpg").convert('L')

# %%
image_array = np.array(image)
gray_arr = np.dot(image_array[...,:3], [0.2989, 0.5870, 0.1140])
# gray_arr
# Out:
# array([164.9666, 183.9713, 172.6869, 159.3017, 169.4823, 138.1912,
#        173.7084, 155.7992, 141.3346, 143.1906, 160.4479, 140.8825,
#        144.7325, 152.4534, 166.5936, 162.942 , 164.3173, 166.3969,
#        143.4059, 155.6234, 172.5177, 161.3981, 159.8979, 182.0157,
#        139.3528, 158.9366, 158.292 , 163.0099, 162.6282, 165.7418,
#        143.013 , 173.909 , 149.4519, 174.9967, 147.5169, 149.0338,
#        187.4097, 181.5703, 168.3779, 171.5175, 177.2947, 159.9116,
#        157.2849, 177.2382, 179.7462, 136.6903, 167.7197, 167.4885,
#        157.4436, 147.6628, 142.3806, 148.0975, 139.3022, 132.3749,
#        118.7477, 112.0876, 104.9221, 100.9116,  86.9079, 105.7873,
#         92.9666,  90.5455,  98.5294,  99.819 ,  84.9649,  88.0499,
#         76.9602,  88.0297, 100.4861,  99.1165,  98.1319,  83.3783,
#         92.134 , 106.7598,  68.962 ,  92.1263,  73.6581,  82.064 ,
#         90.0942,  94.4203, 102.6198, 111.7103,  98.1274,  94.4206,
#         80.1276,  98.4881,  98.2736, 102.181 ,  98.5896,  98.9826,
#        102.404 , 100.3875,  83.0627, 111.9903, 104.9885,  96.8143,
#         92.6069,  91.6611, 105.8464,  77.6004, 109.0039,  94.7007,
#         87.7096, 112.9948,  81.4697, 117.88  ,  82.2865,  79.235 ,
#        103.1082,  97.22  , 108.4898, 106.339 , 118.5368, 113.6109,
#        119.1284, 104.9573,  92.6025,  87.0777,  84.3073, 110.0012,
#         97.5355, 101.2577, 105.6764, 103.3193, 120.0573, 104.1559,
#        117.9203, 102.0144, 100.5788, 104.2699, 104.6721, 103.3319,
#        120.1316,  97.9209,  94.4957, 115.6858, 119.1283, 109.3851,
#         82.5753,  97.7594,  92.9171,  98.69  , 102.5539,  96.1271,
#        100.2212, 107.5101, 106.2837,  96.6342, 101.7727,  93.761 ,
#         94.8796, 104.1052,  89.0452,  83.6831,  82.8999,  92.1112,
#         92.071 ,  82.7226,  93.3941, 112.3342,  91.368 , 100.5152,
#        105.9463, 105.1929, 142.1278,  99.2984,  96.9303,  92.0632,
#        103.1592, 101.9298, 106.4302,  80.9314,  75.8987,  84.6941,
#         75.8955,  91.848 ,  80.1956,  60.9755,  59.6996,  57.044 ,
#         73.3626,  85.1114,  67.9703,  72.458 ,  82.3509,  58.6371,
#         74.8783,  99.5758,  89.1931, 102.6937,  81.128 ,  74.2666,
#         87.9327,  84.8345,  93.6611,  87.6339,  85.6464,  87.6307,
#         71.2333,  64.7798,  48.835 ,  81.4095,  50.776 ,  81.6405,
#         55.9915,  52.0505,  58.4931,  47.7899,  50.0116,  24.0727,
#         60.1559,  45.7181,  60.0234,  78.2653,  30.986 ,  61.4498,
#         60.2563,  49.4558,  74.6089,  32.562 ,  44.6674,  55.8201,
#         50.5805,  35.1691,  77.3361,  18.277 ,  66.1799,  34.4341,
#         69.3599,  52.5231,  75.686 ,  59.131 ,  99.7374, 112.2372,
#        129.4971, 123.1125, 129.8359, 128.7497, 115.6419, 146.4242,
#        111.1632, 136.3902, 127.5635,  73.336 ,  74.7704,  45.7361,
#         53.096 ,  27.2945,  42.3657,  44.5795,  51.8465,  31.2774,
#         24.119 ,  44.1774,  39.8895,  29.8261,  41.6894,  14.5921,
#         32.7562,  35.151 ,  21.6791,  22.107 ,  56.9701,  21.2332,
#         34.1785,  28.3685,  41.7372,  45.6105,  35.8808,  44.1204,
#         42.7354,  13.8766,  29.308 ,  38.1045,  40.799 ,  37.5606,
#         50.3968,  43.4058,  71.3131, 100.7911,  83.8084,  94.4664,
#         88.2589,  96.3573,  88.2205,  92.4143,  65.3859,  51.7631,
#         47.8642,  43.3883,  53.9895,  50.1813,  79.226 ,  64.5346,
#         72.8738,  53.0116,  41.6738,  39.5412,  41.1531,  43.2129])

# %%
def meanfilter(image):
    filter_size = 3

# %%
output = meanfilter(gray_arr)

# %%
output_image = Image.fromarray(output.astype(np.uint8))
output_image.save("output.jpg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 output_image = Image.fromarray(output.astype(np.uint8))
#       2 output_image.save("output.jpg")
#
# AttributeError: 'NoneType' object has no attribute 'astype'
